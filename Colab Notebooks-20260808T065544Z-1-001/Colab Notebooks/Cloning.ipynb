# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone without files
# !git clone --no-checkout https://github.com/PENUMARTHIHIMAVARSHINI/Dementia-.git

# %cd Dementia-

# Enable sparse checkout
# !git sparse-checkout init --cone

# ONLY required folders
# !git sparse-checkout set control dementia

# Pull them
# !git checkout
# Out:
# Cloning into 'Dementia-'...
# remote: Enumerating objects: 5055, done.
# remote: Counting objects: 100% (1919/1919), done.
# remote: Compressing objects: 100% (1891/1891), done.
# remote: Total 5055 (delta 643), reused 0 (delta 0), pack-reused 3136 (from 2)
# Receiving objects: 100% (5055/5055), 1.18 GiB | 25.52 MiB/s, done.
# Resolving deltas: 100% (1752/1752), done.
# /content/Dementia-
# Updating files: 100% (4103/4103), done.
# Your branch is up to date with 'origin/main'.

# %%
# Create a folder in Drive (optional)
# !mkdir -p /content/drive/MyDrive/Dementia_Data

# Copy folders
# !cp -r control /content/drive/MyDrive/Dementia_Data/
# !cp -r dementia /content/drive/MyDrive/Dementia_Data/

# %%
# !ls /content/drive/MyDrive/Dementia_Data
# Out:
# control  dementia
